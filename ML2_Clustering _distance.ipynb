# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import pairwise_distances_argmin_min
import numpy as np

# %%
application_rec = pd.read_csv('Data_For_Clustering.csv')
application_rec.sample(5)
# Out:
#         Unnamed: 0  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  \
# 139769      139769            1             0                0
# 6482          6482            1             0                0
# 141151      141151            0             0                1
# 99345        99345            1             1                0
# 218790      218790            0             0                1
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 139769          202500.0               Working  Secondary / secondary special
# 6482            148500.0               Working  Secondary / secondary special
# 141151          270000.0         State servant               Higher education
# 99345           270000.0  Commercial associate               Higher education
# 218790          360000.0  Commercial associate               Higher education
#
#           NAME_FAMILY_STATUS    NAME_HOUSING_TYPE  FLAG_MOBIL  \
# ...

# %%
application_rec.reset_index(inplace=True)
application_rec = application_rec.drop(['Unnamed: 0', 'index'], axis=1)

# %%
application_rec = application_rec.dropna()

# %%
data=application_rec

# %%
import numpy as np

# Custom distance function for categorical variables
def custom_distance_categorical(x, y):
    return np.sum(x != y)

# Custom distance function for numeric variables
def custom_distance_numeric(x, y):
    return np.linalg.norm(x - y)

# Custom distance function for binary variables
def custom_distance_binary(x, y):
    return np.sum(x != y)

def k_means(data, k, distance_funcs):
    # Randomly initialize centroids
    indices = np.random.choice(len(data), k, replace=False)
    centroids = data[indices]

    while True:
        # Initialize empty clusters
        clusters = [[] for _ in range(k)]

        # Assign data points to clusters
        for point in data:
            distances = [distance_funcs[variable_type](point[i], centroids[closest_centroid][i]) for i, variable_type in enumerate(variable_types)]
            closest_centroid = np.argmin(distances)
            clusters[closest_centroid].append(point)

        # Update centroids
        new_centroids = []
        for cluster in clusters:
            if len(cluster) > 0:
                new_centroids.append(np.mean(cluster, axis=0))
            else:
                new_centroids.append(centroids[0])  # Keep the same centroid if empty cluster

        # Convert to numpy array for easier calculations
        new_centroids = np.array(new_centroids)

        # Check convergence
        if np.allclose(new_centroids, centroids):
            break

        centroids = new_centroids

    return centroids, clusters

# Example usage

# Define the data
column_names = ["NAME_INCOME_TYPE", "NAME_EDUCATION_TYPE", "NAME_FAMILY_STATUS", "NAME_HOUSING_TYPE", "OCCUPATION_TYPE", "AMT_INCOME_TOTAL", "AGE", "CODE_GENDER", "FLAG_OWN_CAR", "FLAG_OWN_REALTY", "FLAG_MOBIL", "FLAG_WORK_PHONE", "FLAG_PHONE", "FLAG_EMAIL", "employment_status"]

# Define the variable types
variable_types = ['categorical', 'categorical', 'categorical', 'categorical', 'categorical', 'numeric', 'numeric', 'binary', 'binary', 'binary', 'binary', 'binary', 'binary', 'binary', 'categorical']

# Define the custom distance functions for each variable type
distance_funcs = {
    'categorical': custom_distance_categorical,
    'numeric': custom_distance_numeric,
    'binary': custom_distance_binary
}

# Define the number of clusters
k = 3

# Perform k-means clustering
centroids, clusters = k_means(data[column_names].values, k, distance_funcs)

# Retrieve the labels of the data points
labels = np.zeros(len(data))
for i, cluster in enumerate(np.array(clusters)):
    labels[cluster] = i

# Print the labels
print(labels)
# Out:
# C:\Users\shula\AppData\Local\Temp\ipykernel_24012\940525926.py:68: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   centroids, clusters = k_means(data[column_names].values, k, distance_funcs)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24012\940525926.py in <module>
#      66
#      67 # Perform k-means clustering
# ---> 68 centroids, clusters = k_means(data[column_names].values, k, distance_funcs)
#      69
#      70 # Retrieve the labels of the data points
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
import numpy as np

# Custom distance function for categorical variables
def custom_distance_categorical(x, y):
    return np.sum(x != y)

# Custom distance function for numeric variables
def custom_distance_numeric(x, y):
    return np.linalg.norm(x - y)

# Custom distance function for binary variables
def custom_distance_binary(x, y):
    return np.sum(x != y)

def k_means(data, k, distance_funcs):
    # Randomly initialize centroids
    indices = np.random.choice(len(data), k, replace=False)
    centroids = data[indices]

    while True:
        # Initialize empty clusters
        clusters = [[] for _ in range(k)]

        # Assign data points to clusters
        for point in data:
            distances = [distance_funcs[variable_type](point[i], centroids[closest_centroid][i]) for i, variable_type in enumerate(variable_types)]
            closest_centroid = np.argmin(distances)
            clusters[closest_centroid].append(point)

        # Update centroids
        new_centroids = []
        for cluster in clusters:
            if len(cluster) > 0:
                new_centroids.append(np.mean(cluster, axis=0))
            else:
                new_centroids.append(centroids[0])  # Keep the same centroid if empty cluster

        # Convert to numpy array for easier calculations
        new_centroids = np.array(new_centroids)

        # Check convergence
        if np.allclose(new_centroids, centroids):
            break

        centroids = new_centroids

    return centroids, clusters

# Example usage

# Define the data
data = np.array([
    # Add your own data rows here
])

# Define the column names
column_names = ["NAME_INCOME_TYPE", "NAME_EDUCATION_TYPE", "NAME_FAMILY_STATUS", "NAME_HOUSING_TYPE", "OCCUPATION_TYPE", "AMT_INCOME_TOTAL", "AGE", "CODE_GENDER", "FLAG_OWN_CAR", "FLAG_OWN_REALTY", "FLAG_MOBIL", "FLAG_WORK_PHONE", "FLAG_PHONE", "FLAG_EMAIL", "employment_status"]

# Define the variable types
variable_types = ['categorical', 'categorical', 'categorical', 'categorical', 'categorical', 'numeric', 'numeric', 'binary', 'binary', 'binary', 'binary', 'binary', 'binary', 'binary', 'categorical']

# Define the custom distance functions for each variable type
distance_funcs = {
    'categorical': custom_distance_categorical,
    'numeric': custom_distance_numeric,
    'binary': custom_distance_binary
}

# Define the number of clusters
k = 3

# Perform k-means clustering
centroids, clusters = k_means(data, k, distance_funcs)

# Retrieve the labels of the data points
labels = np.zeros(len(data))
for i, cluster in enumerate(clusters):
    for point in cluster:
        index = np.where((data == point).all(axis=1))[0]
        labels[index] = i

# Print the labels
print(labels)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24012\814886754.py in <module>
#      71
#      72 # Perform k-means clustering
# ---> 73 centroids, clusters = k_means(data, k, distance_funcs)
#      74
#      75 # Retrieve the labels of the data points
#
# ~\AppData\Local\Temp\ipykernel_24012\814886754.py in k_means(data, k, distance_funcs)
#      15 def k_means(data, k, distance_funcs):
#      16     # Randomly initialize centroids
# ---> 17     indices = np.random.choice(len(data), k, replace=False)
#      18     centroids = data[indices]
#      19
#
# mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# ValueError: a must be greater than 0 unless no samples are taken

# %%
import numpy as np

# Custom distance function for categorical variables
def custom_distance_categorical(x, y):
    return np.sum(x != y)

# Custom distance function for numeric variables
def custom_distance_numeric(x, y):
    return np.linalg.norm(x - y)

# Custom distance function for binary variables
def custom_distance_binary(x, y):
    return np.sum(x != y)

def k_means(data, k, distance_funcs):
    # Randomly initialize centroids
    indices = np.random.choice(len(data), k, replace=True)
    centroids = data[indices]

    while True:
        # Initialize empty clusters
        clusters = [[] for _ in range(k)]

        # Assign data points to clusters
        for point_index, point in enumerate(data):
            closest_centroid = None  # Initialize closest centroid
            closest_distance = float('inf')  # Initialize closest distance to infinity
            
            # Calculate distances and find the closest centroid
            for i, centroid in enumerate(centroids):
                distances = [distance_funcs[variable_type](point[j], centroid[j]) for j, variable_type in enumerate(variable_types)]
                distance = np.sum(distances)
                if distance < closest_distance:
                    closest_centroid = i
                    closest_distance = distance
            
            clusters[closest_centroid].append(point_index)

        # Update centroids
        new_centroids = []
        for cluster in clusters:
            if len(cluster) > 0:
                new_centroids.append(np.mean(data[cluster], axis=0))
            else:
                new_centroids.append(centroids[0])  # Keep the same centroid if empty cluster

        # Convert to numpy array for easier calculations
        new_centroids = np.array(new_centroids)

        # Check convergence
        if np.allclose(new_centroids, centroids):
            break

        centroids = new_centroids

    return centroids, clusters

# Example usage

# Define the data
data = np.array([data])

# Define the column names
column_names = ["NAME_INCOME_TYPE", "NAME_EDUCATION_TYPE", "NAME_FAMILY_STATUS", "NAME_HOUSING_TYPE", "OCCUPATION_TYPE", "AMT_INCOME_TOTAL", "AGE", "CODE_GENDER", "FLAG_OWN_CAR", "FLAG_OWN_REALTY", "FLAG_MOBIL", "FLAG_WORK_PHONE", "FLAG_PHONE", "FLAG_EMAIL", "employment_status"]

# Define the variable types
variable_types = ['categorical', 'categorical', 'categorical', 'categorical', 'categorical', 'numeric', 'numeric', 'binary', 'binary', 'binary', 'binary', 'binary', 'binary', 'binary', 'categorical']

# Define the custom distance functions for each variable type
distance_funcs = {
    'categorical': custom_distance_categorical,
    'numeric': custom_distance_numeric,
    'binary': custom_distance_binary
}

# Define the number of clusters
k = 3

# Perform k-means clustering
centroids, clusters = k_means(data, k, distance_funcs)

# Retrieve the labels of the data points
labels = np.zeros(len(data))
for i, cluster in enumerate(clusters):
    for point_index in cluster:
        labels[point_index] = i

# Print the labels
print(labels)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24012\3691642895.py in <module>
#      78
#      79 # Perform k-means clustering
# ---> 80 centroids, clusters = k_means(data, k, distance_funcs)
#      81
#      82 # Retrieve the labels of the data points
#
# ~\AppData\Local\Temp\ipykernel_24012\3691642895.py in k_means(data, k, distance_funcs)
#      29             # Calculate distances and find the closest centroid
#      30             for i, centroid in enumerate(centroids):
# ---> 31                 distances = [distance_funcs[variable_type](point[j], centroid[j]) for j, variable_type in enumerate(variable_types)]
#      32                 distance = np.sum(distances)
#      33                 if distance < closest_distance:
#
# ~\AppData\Local\Temp\ipykernel_24012\3691642895.py in <listcomp>(.0)
# ...
